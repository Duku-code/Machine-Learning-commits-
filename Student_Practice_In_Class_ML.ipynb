# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cancer = pd.read_csv("data_fahz1.csv")
cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
cancer.shape
# Out:
# (569, 33)

# %%
cancer.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  texture_worst  perimeter_worst   area_worst  \
# count     569.000000  ...     569.000000       569.000000   569.000000
# mean        0.181162  ...      25.677223       107.261213   880.583128
# std         0.027414  ...       6.146258        33.602542   569.356993
# min         0.106000  ...      12.020000        50.410000   185.200000
# 25%         0.161900  ...      21.080000        84.110000   515.300000
# 50%         0.179200  ...      25.410000        97.660000   686.500000
# 75%         0.195700  ...      29.720000       125.400000  1084.000000
# max         0.304000  ...      49.540000       251.200000  4254.000000
#
#        smoothness_worst  compactness_worst  concavity_worst  \
# count        569.000000         569.000000       569.000000
# mean           0.132369           0.254265         0.272188
# std            0.022832           0.157336         0.208624
# min            0.071170           0.027290         0.000000
# 25%            0.116600           0.147200         0.114500
# 50%            0.131300           0.211900         0.226700
# 75%            0.146000           0.339100         0.382900
# max            0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst  \
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
#        Unnamed: 32
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [8 rows x 32 columns]

# %%
cancer.diagnosis = cancer.diagnosis.map({'M':1 , 'B':0})

# %%
cancer.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
#Here we are dropping two columns i.e.diagnosis & id
x = cancer.drop(['diagnosis','id'], axis=1)
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  Unnamed: 32
# 0          0.4601                  0.11890          NaN
# 1          0.2750                  0.08902          NaN
# 2          0.3613                  0.08758          NaN
# 3          0.6638                  0.17300          NaN
# 4          0.2364                  0.07678          NaN
#
# [5 rows x 31 columns]

# %%
#Here we are saving target column i.e.diagnonis separately 
y = cancer.diagnosis
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %%
x.isnull().sum()*100/len(x)
# Out:
# radius_mean                  0.0
# texture_mean                 0.0
# perimeter_mean               0.0
# area_mean                    0.0
# smoothness_mean              0.0
# compactness_mean             0.0
# concavity_mean               0.0
# concave points_mean          0.0
# symmetry_mean                0.0
# fractal_dimension_mean       0.0
# radius_se                    0.0
# texture_se                   0.0
# perimeter_se                 0.0
# area_se                      0.0
# smoothness_se                0.0
# compactness_se               0.0
# concavity_se                 0.0
# concave points_se            0.0
# symmetry_se                  0.0
# fractal_dimension_se         0.0
# radius_worst                 0.0
# texture_worst                0.0
# perimeter_worst              0.0
# area_worst                   0.0
# smoothness_worst             0.0
# compactness_worst            0.0
# concavity_worst              0.0
# concave points_worst         0.0
# symmetry_worst               0.0
# fractal_dimension_worst      0.0
# Unnamed: 32                100.0
# dtype: float64

# %%
x = x.drop(['Unnamed: 32'], axis=1)
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
x.shape
# Out:
# (569, 30)

# %%
x.var()
# Out:
# radius_mean                    12.418920
# texture_mean                   18.498909
# perimeter_mean                590.440480
# area_mean                  123843.554318
# smoothness_mean                 0.000198
# compactness_mean                0.002789
# concavity_mean                  0.006355
# concave points_mean             0.001506
# symmetry_mean                   0.000752
# fractal_dimension_mean          0.000050
# radius_se                       0.076902
# texture_se                      0.304316
# perimeter_se                    4.087896
# area_se                      2069.431583
# smoothness_se                   0.000009
# compactness_se                  0.000321
# concavity_se                    0.000911
# concave points_se               0.000038
# symmetry_se                     0.000068
# fractal_dimension_se            0.000007
# radius_worst                   23.360224
# texture_worst                  37.776483
# perimeter_worst              1129.130847
# area_worst                 324167.385102
# smoothness_worst                0.000521
# compactness_worst               0.024755
# concavity_worst                 0.043524
# concave points_worst            0.004321
# symmetry_worst                  0.003828
# fractal_dimension_worst         0.000326
# dtype: float64

# %%
x_v = x/x.mean()
x_v.var()
# Out:
# radius_mean                0.062225
# texture_mean               0.049716
# perimeter_mean             0.069806
# area_mean                  0.288761
# smoothness_mean            0.021302
# compactness_mean           0.256193
# concavity_mean             0.805960
# concave points_mean        0.629172
# symmetry_mean              0.022899
# fractal_dimension_mean     0.012641
# radius_se                  0.468447
# texture_se                 0.205517
# perimeter_se               0.497656
# area_se                    1.271868
# smoothness_se              0.181847
# compactness_se             0.494046
# concavity_se               0.895783
# concave points_se          0.273609
# symmetry_se                0.161932
# fractal_dimension_se       0.486185
# radius_worst               0.088256
# texture_worst              0.057296
# perimeter_worst            0.098143
# area_worst                 0.418050
# smoothness_worst           0.029753
# compactness_worst          0.382900
# concavity_worst            0.587476
# concave points_worst       0.328959
# symmetry_worst             0.045489
# fractal_dimension_worst    0.046291
# dtype: float64

# %%
x_v.var()>0.03
# Out:
# radius_mean                 True
# texture_mean                True
# perimeter_mean              True
# area_mean                   True
# smoothness_mean            False
# compactness_mean            True
# concavity_mean              True
# concave points_mean         True
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                   True
# texture_se                  True
# perimeter_se                True
# area_se                     True
# smoothness_se               True
# compactness_se              True
# concavity_se                True
# concave points_se           True
# symmetry_se                 True
# fractal_dimension_se        True
# radius_worst                True
# texture_worst               True
# perimeter_worst             True
# area_worst                  True
# smoothness_worst           False
# compactness_worst           True
# concavity_worst             True
# concave points_worst        True
# symmetry_worst              True
# fractal_dimension_worst     True
# dtype: bool

# %%
x = x.loc[:,x_v.var()>0.03]
x.shape
# Out:
# (569, 26)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state = 29)
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
rf.feature_importances_
# Out:
# array([0.05595653, 0.01971743, 0.0435665 , 0.0339168 , 0.00728505,
#        0.05038539, 0.13928371, 0.01408646, 0.00317712, 0.02386835,
#        0.03227377, 0.00443328, 0.00527278, 0.00658779, 0.00418338,
#        0.00634471, 0.00527187, 0.09966808, 0.02197046, 0.10032013,
#        0.12587478, 0.01364673, 0.02968268, 0.13633959, 0.00990442,
#        0.00698218])

# %%
rf_feat = pd.Series(rf.feature_importances_, index= x_train.columns)
rf_feat
# Out:
# radius_mean                0.055957
# texture_mean               0.019717
# perimeter_mean             0.043566
# area_mean                  0.033917
# compactness_mean           0.007285
# concavity_mean             0.050385
# concave points_mean        0.139284
# radius_se                  0.014086
# texture_se                 0.003177
# perimeter_se               0.023868
# area_se                    0.032274
# smoothness_se              0.004433
# compactness_se             0.005273
# concavity_se               0.006588
# concave points_se          0.004183
# symmetry_se                0.006345
# fractal_dimension_se       0.005272
# radius_worst               0.099668
# texture_worst              0.021970
# perimeter_worst            0.100320
# area_worst                 0.125875
# compactness_worst          0.013647
# concavity_worst            0.029683
# concave points_worst       0.136340
# symmetry_worst             0.009904
# fractal_dimension_worst    0.006982
# dtype: float64

# %%
x = x.loc[:, rf_feat>0.01]
x.shape
# Out:
# (569, 16)

# %%
x_cor = x.corr()>0.95

# %%
x_cor
# Out:
#                       radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                  True         False            True       True
# texture_mean                False          True           False      False
# perimeter_mean               True         False            True       True
# area_mean                    True         False            True       True
# concavity_mean              False         False           False      False
# concave points_mean         False         False           False      False
# radius_se                   False         False           False      False
# perimeter_se                False         False           False      False
# area_se                     False         False           False      False
# radius_worst                 True         False            True       True
# texture_worst               False         False           False      False
# perimeter_worst              True         False            True       True
# area_worst                  False         False           False       True
# compactness_worst           False         False           False      False
# concavity_worst             False         False           False      False
# concave points_worst        False         False           False      False
#
#                       concavity_mean  concave points_mean  radius_se  \
# radius_mean                    False                False      False
# texture_mean                   False                False      False
# perimeter_mean                 False                False      False
# area_mean                      False                False      False
# concavity_mean                  True                False      False
# concave points_mean            False                 True      False
# radius_se                      False                False       True
# perimeter_se                   False                False       True
# area_se                        False                False       True
# radius_worst                   False                False      False
# texture_worst                  False                False      False
# perimeter_worst                False                False      False
# area_worst                     False                False      False
# compactness_worst              False                False      False
# concavity_worst                False                False      False
# concave points_worst           False                False      False
#
#                       perimeter_se  area_se  radius_worst  texture_worst  \
# radius_mean                  False    False          True          False
# texture_mean                 False    False         False          False
# perimeter_mean               False    False          True          False
# area_mean                    False    False          True          False
# concavity_mean               False    False         False          False
# concave points_mean          False    False         False          False
# radius_se                     True     True         False          False
# perimeter_se                  True    False         False          False
# area_se                      False     True         False          False
# radius_worst                 False    False          True          False
# texture_worst                False    False         False           True
# perimeter_worst              False    False          True          False
# area_worst                   False    False          True          False
# compactness_worst            False    False         False          False
# concavity_worst              False    False         False          False
# concave points_worst         False    False         False          False
#
#                       perimeter_worst  area_worst  compactness_worst  \
# radius_mean                      True       False              False
# texture_mean                    False       False              False
# perimeter_mean                   True       False              False
# area_mean                        True        True              False
# concavity_mean                  False       False              False
# concave points_mean             False       False              False
# radius_se                       False       False              False
# perimeter_se                    False       False              False
# area_se                         False       False              False
# radius_worst                     True        True              False
# texture_worst                   False       False              False
# perimeter_worst                  True        True              False
# area_worst                       True        True              False
# compactness_worst               False       False               True
# concavity_worst                 False       False              False
# concave points_worst            False       False              False
#
#                       concavity_worst  concave points_worst
# radius_mean                     False                 False
# texture_mean                    False                 False
# perimeter_mean                  False                 False
# area_mean                       False                 False
# concavity_mean                  False                 False
# concave points_mean             False                 False
# radius_se                       False                 False
# perimeter_se                    False                 False
# area_se                         False                 False
# radius_worst                    False                 False
# texture_worst                   False                 False
# perimeter_worst                 False                 False
# area_worst                      False                 False
# compactness_worst               False                 False
# concavity_worst                  True                 False
# concave points_worst            False                  True

# %%
x_cor['radius_mean']
# Out:
# radius_mean              True
# texture_mean            False
# perimeter_mean           True
# area_mean                True
# concavity_mean          False
# concave points_mean     False
# radius_se               False
# perimeter_se            False
# area_se                 False
# radius_worst             True
# texture_worst           False
# perimeter_worst          True
# area_worst              False
# compactness_worst       False
# concavity_worst         False
# concave points_worst    False
# Name: radius_mean, dtype: bool

# %%
x = x.drop(['perimeter_mean','radius_worst','perimeter_worst'], axis=1)
x.shape
# Out:
# (569, 13)

# %%
pred_tree = rf.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_tree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       104
#            1       0.97      0.93      0.95        67
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.95      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,pred_tree))
# Out:
# [[102   2]
#  [  5  62]]

# %%
cancer["radius_mean"].hist(bins=20)
# Out:
# <Axes: >

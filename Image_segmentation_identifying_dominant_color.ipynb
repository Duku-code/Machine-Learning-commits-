# %% [markdown]
# <a href="https://colab.research.google.com/github/Duku-code/Duku/blob/main/Image_segmentation_identifying_dominant_color.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
from sklearn.cluster import KMeans

# %%
image = Image.open('duku.jpg')

# %%
from matplotlib import pyplot as plot

# %matplotlib inline

plot.imshow(image)

# %%
import numpy as np

image_np = np.asarray(image)

# %%
image_np.shape
# Out:
# (560, 560, 3)

# %%
image_np = image_np.reshape((560*560,3))

# %%
image_np.shape
# Out:
# (313600, 3)

# %%
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(image_np)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=0)

# %%
labels = kmeans.predict(image_np)

# %%
labels = labels.reshape((560, 560))

# %%
plot.imshow(labels)

# %%
centers = [centers.astype(int) for centers in kmeans.cluster_centers_]

# %%
blob = np.ones((100,100,3))

# %%
blob1 = blob * centers[0]

# %%
plot.imshow(blob1)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
blob2 = blob * centers[1]
plot.imshow(blob2)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
blob2=blob2.astype(int)
blob2
# Out:
# array([[[43, 33, 83],
#         [43, 33, 83],
#         [43, 33, 83],
#         ...,
#         [43, 33, 83],
#         [43, 33, 83],
#         [43, 33, 83]],
#
#        [[43, 33, 83],
#         [43, 33, 83],
#         [43, 33, 83],
#         ...,
#         [43, 33, 83],
#         [43, 33, 83],
#         [43, 33, 83]],
#
#        [[43, 33, 83],
#         [43, 33, 83],
#         [43, 33, 83],
#         ...,
#         [43, 33, 83],
#         [43, 33, 83],
#         [43, 33, 83]],
#
#        ...,
#
#        [[43, 33, 83],
#         [43, 33, 83],
#         [43, 33, 83],
#         ...,
#         [43, 33, 83],
#         [43, 33, 83],
#         [43, 33, 83]],
#
#        [[43, 33, 83],
#         [43, 33, 83],
#         [43, 33, 83],
#         ...,
#         [43, 33, 83],
#         [43, 33, 83],
#         [43, 33, 83]],
#
#        [[43, 33, 83],
#         [43, 33, 83],
#         [43, 33, 83],
#         ...,
#         [43, 33, 83],
#         [43, 33, 83],
#         [43, 33, 83]]])

# %%
blob3 = blob * centers[2]
plot.imshow(blob3)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
centers
# Out:
# [array([247, 220, 199]), array([43, 33, 83]), array([176, 123, 134])]
